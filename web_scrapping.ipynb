# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
web = requests.get("https://www.elle.com")

# %%
web
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(web.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="https://www.elle.com/" rel="canonical"/>
#   <meta content="IE=edge,chrom=1" http-equiv="X-UA-Compatible" name="X-UA-Compatible"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <title>
#    Fashion Magazine - Beauty Tips, Fashion Trends, &amp; Celebrity News - ELLE
#   </title>
#   <meta content="Fashion Magazine - Beauty Tips, Fashion Trends, &amp; Celebrity News - ELLE" name="title"/>
#   <meta content="Watch runway shows from the hottest fashion designers, scope out the best-dressed celebrities on the red carpet, discover the latest and greatest beauty products to maintain a healthy glow, and get a sneak peek at our celebrity cover shoots." name="description"/>
#   <meta content="" name="keywords"/>
#   <meta content="website" property="og:type"/>
#   <meta content="#000000" name="theme-color"/>
# ...

# %%
img=soup.find_all("img")

# %%
for i in img:
    print(i.get("src"))
# Out:
# /_assets/design-tokens/fre/static/icons/search.f1c199c.svg
# /_assets/design-tokens/fre/static/icons/close.38e3324.svg
# /_assets/design-tokens/elle/static/images/logos/logo.2856426.svg?primary=navLogoColor
# https://hips.hearstapps.com/hmg-prod/images/hannah-berner-2-668d5a7aa493f.png?crop=1.00xw:0.670xh;0,0.160xh&resize=1200:*
# https://hips.hearstapps.com/hmg-prod/images/elle-substack-index-668c2a662a751.jpg?crop=1.00xw:1.00xh;0,0&resize=1200:*
# https://hips.hearstapps.com/hmg-prod/images/elm050123wlcolorful-005-2-6642320a2b71a.jpg?crop=0.886xw:0.560xh;0.0272xw,0.0628xh&resize=360:*
# https://hips.hearstapps.com/hmg-prod/images/celine-elm-0521240726-665f7cb6231e8.jpg?crop=0.742xw:1.00xh;0.130xw,0&resize=360:*
# https://hips.hearstapps.com/hmg-prod/images/ba-sh-ara-bag-6657c4f39bc29.jpg?crop=0.668xw:1.00xh;0.167xw,0&resize=360:*
# https://hips.hearstapps.com/hmg-prod/images/elm080123wlchristian-002-66579069963c5.jpg?crop=1.00xw:0.736xh;0,0&resize=360:*
# ...

# %%
web2=requests.get("https://www.vogue.in/")
web2
# Out:
# <Response [200]>

# %%
soup2=BeautifulSoup(web2.content,"html.parser")
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-IN">
#  <head>
#   <title>
#    VOGUE India: Women's Magazine for Beauty, Fashion, Lifestyle &amp; Entertainment | Vogue India
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="no" name="msapplication-tap-highlight"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Condé Nast" name="author"/>
#   <meta content="Copyright (c) Condé Nast 2024" name="copyright"/>
#   <meta content="VOGUE India is the one-stop destination for women's fashion, beauty, lifestyle and entertainment content. Get fashion &amp; beauty tips from experts, and celeb-inspiration for looks, home decor, and more." name="description"/>
#   <meta content="602f972c97a6d928a4e6e920" name="id"/>
#   <meta content="" name="keywords"/>
#   <meta content="" name="news_keywords"/>
#   <meta content="index, follow, max-image-preview:large" name="robots"/>
# ...

# %%
text=soup2.find_all("p")
for t in text:
    print(t)
# Out:
# <p>To revisit this article, visit My Profile, then<!-- --> <a href="/account/saved">View saved stories</a></p>
# <p>To revisit this article, visit My Profile, then<!-- --> <a href="/account/saved">View saved stories</a></p>
# <p class="NavigationHeadingWrapper-befTuI kSFYXD navigation__heading" data-testid="navigation__heading"><button aria-expanded="false" class="NavigationHeadingButton-eDVixB fiYwDK" data-testid="navigation__heading-button" type="button">See more stories<span class="NavigationHeadingArrow-iJeTMa gGaHQm" data-testid="navigation__heading-arrow"></span></button></p>
# <p class="NavigationHeadingWrapper-befTuI kSFYXD navigation__heading" data-testid="navigation__heading"><button aria-expanded="false" class="NavigationHeadingButton-eDVixB fiYwDK" data-testid="navigation__heading-button" type="button">Condé Nast India<span class="NavigationHeadingArrow-iJeTMa gGaHQm" data-testid="navigation__heading-arrow"></span></button></p>
# ...

# %%
def extract_text(soup2):
    # Remove script and style elements
    for script_or_style in soup2(['script', 'style']):
        script_or_style.decompose()
    
    # Get the text and clean it
    text = soup2.get_text(separator=' ')
    lines = (line.strip() for line in text.splitlines())
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    text = '\n'.join(chunk for chunk in chunks if chunk)
    
    return text

text = extract_text(soup)
print(text)
# Out:
# Fashion Magazine - Beauty Tips, Fashion Trends, & Celebrity News - ELLE Search Subscribe Fashion Beauty Home Shopping Culture News & Politics Horoscopes Weddings In the Magazine Newsletter Follow Other Editions Privacy Notice Terms Of Use Skip to Content Fashion Beauty Culture News & Politics Horoscopes Subscribe PROFILE Hannah Berner Took the Funniest Possible Road to Fame
# The
# We Ride at Dawn
# comedian didn’t mean to launch a stand-up career. She just couldn’t help herself.
# ...
